# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import flask

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("scikit-learn:", sklearn.__version__)
print("flask:", flask.__version__)
print("✅ All good — ready to build!")
# Out:
# pandas: 3.0.3
# numpy: 2.4.6
# scikit-learn: 1.9.0
# flask: 3.1.3
# ✅ All good — ready to build!
# C:\Users\Prathish Thiyageson\AppData\Local\Temp\ipykernel_16780\2743209877.py:10: DeprecationWarning: The '__version__' attribute is deprecated and will be removed in Flask 3.2. Use feature detection or 'importlib.metadata.version("flask")' instead.
#   print("flask:", flask.__version__)
